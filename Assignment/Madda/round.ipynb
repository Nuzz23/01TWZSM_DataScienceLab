# %%
import pandas as pd

# %%
data = pd.read_csv('./9-100.csv', index_col=0)
display(data)
# Out:
#      Predicted
# Id
# 0    34.224864
# 1    31.504342
# 2    25.117859
# 3    27.899742
# 4    35.900536
# ..         ...
# 686  23.500067
# 687  27.599096
# 688  26.082026
# 689  30.263196
# 690  20.132970
#
# [691 rows x 1 columns]

# %%
data['Predicted'] = data['Predicted'].map(lambda x: int(x) if 0<=x-int(x)<0.5 else int(x)+1)
#data['Predicted'] = data['Predicted'].map(lambda x: int(x)+0.5 if 0.25<=x-int(x)<0.75 else x)
#data['Predicted'] = data['Predicted'].map(lambda x: int(x)+1 if 0.75<=x-int(x)<1 else x)

# %%
data.to_csv('9-100_rounded2.csv')
