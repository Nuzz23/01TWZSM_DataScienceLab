# %% [markdown]
# All the libraries, modules, imports and constant used in this file

# %%
from json import load
import pandas as pd # type: ignore 
import mlxtend # type: ignore

FILE_INPUT = "modified_coco.json"
FILE_INPUT_TOY = "toy_dataset.txt"
THRESHOLD = 1
READ_TOY_DATA = False
MIN_SUPPORT = 0.02
MAX_LEN_ITEMSETS = None
USE_APRIORI = 0

# %% [markdown]
# This function reads a toy dataset from file to implement the apriori principle

# %%
def readToyDatasetFile(file:str)->[set[tuple[str]], set[str]]:  # type: ignore
    data = set()
    singleItems = set()
    with open(file, "r", encoding='UTF-8') as fp:
        for line in fp:
            line = tuple(line.strip().split(","))
            data.add(line)
            for item in line:
                singleItems.add(item)
            
    return [data, singleItems]

# %% [markdown]
# This function reads the coco dataset

# %%
def readFile(file:str)->list[list[dict], set[str]]:
    with open(file, "r", encoding='UTF-8') as fp:
        data = load(fp)
    
    return data, {el for item in data for el in item['annotations']}

# %% [markdown]
# This function creates the matrix data frame for the data as a sparse matrix

# %%
def createDataFrame(data:list[dict], columnsName:list[str])->list[list[bool]]:
    return pd.DataFrame([[column in element['annotations'] for column in columnsName] for element in data],
                        index=[element['image_id'] for element in data], columns=columnsName)

# %% [markdown]
# This function counts the number of times the itemsets of length length are in the dataset

# %%
def countOccurrences(data:list[dict], items:set[tuple], length:int)->dict[tuple:int]:
    return {tuple(item): sum(1 for row in data if len(set(item).intersection(set(row['annotations']))) == len(item)) for item in set(filter(lambda x : len(x)<= length, items))}

# %% [markdown]
# This function searches for pictures with that contains all the given characteristic

# %%
def searchPictureWithItemSet(data:list[dict], words:set[str])->list[int, str, str]:
    return [[index, item['file_name'], item['image_id']] for index, item in enumerate(data) if words.issubset(set(item['annotations']))]

# %% [markdown]
# This is the main function of the program that will control all the flow
# <ol>
# <li>Reads the toy data set or the new data set</li>
# <li>Creates the data frame from the given data</li>
# <li>Executes the fp growth algorithm</li>
# <li>Executes the apriori algorithm</li>
# <li>Searches for pictures matching a given description</li>
# <li>Counts and prints the occurrences of the items found by fp or ap in the given item set</li>
# </ol>

# %%
def main() -> None:
    [data, singleItems] = readToyDatasetFile(FILE_INPUT_TOY) if READ_TOY_DATA else readFile(FILE_INPUT) 

    matrix = createDataFrame(sorted(data, key=lambda x:x['image_id']), sorted(singleItems))

    fp = mlxtend.frequent_patterns.fpgrowth(df=matrix, min_support=MIN_SUPPORT, use_colnames=True, max_len=MAX_LEN_ITEMSETS)
    print(len(fp), "\n", fp.to_string())


    if USE_APRIORI: 
        ap = mlxtend.frequent_patterns.apriori(df=matrix, min_support=MIN_SUPPORT, use_colnames=True, max_len=MAX_LEN_ITEMSETS)
        print(len(ap), "\n", ap.to_string())


    
    for picture_id in searchPictureWithItemSet(data, {'baseball bat', 'baseball glove', 'bench', 'person'}):
        print(picture_id)


    """
    occurrences = countOccurrences(data, set(ap.itemsets), length=2)
    
    for item in sorted(list(map(lambda x:[x, occurrences[x]], occurrences.keys())), key=lambda y:y[1], reverse=True):
        print(f"item {list(item[0])} : {item[1]}")
    
    # The same thing actually
    print("\n")
    for item in sorted(zip(fp.support, fp.itemsets), key=lambda x:x[0], reverse=True):
        print(f"item {list(item[1])} : {int(item[0]*len(data))}")
    """
    
    
main()
# Out:
# 144
#       support                                       itemsets
# 0     0.5886                                       (person)
# 1     0.4338                                        (bench)
# 2     0.0276                                          (dog)
# 3     0.1332                                    (stop sign)
# 4     0.0492                                        (train)
# 5     0.3230                                (traffic light)
# 6     0.3704                                          (car)
# 7     0.1286                                        (truck)
# 8     0.0912                                          (bus)
# 9     0.0554                                (parking meter)
# 10    0.0332                                        (clock)
# 11    0.0852                                     (backpack)
# 12    0.0762                                      (bicycle)
# 13    0.0386                                 (dining table)
# 14    0.0200                                         (bird)
# 15    0.0474                                     (umbrella)
# 16    0.0602                                        (chair)
# 17    0.0344                                   (skateboard)
# 18    0.0368                                  (sports ball)
# 19    0.0214                                (tennis racket)
# 20    0.0410                                   (motorcycle)
# 21    0.1230                                      (handbag)
# 22    0.0202                                     (suitcase)
# 23    0.1346                                 (fire hydrant)
# 24    0.0334                                 (baseball bat)
# 25    0.0300                               (baseball glove)
# 26    0.0354                                   (cell phone)
# 27    0.0280                                       (bottle)
# 28    0.0418                                 (potted plant)
# 29    0.0222                                          (cup)
# 30    0.3208                                (person, bench)
# 31    0.0206                                   (dog, bench)
# 32    0.0202                                  (person, dog)
# 33    0.0470                            (person, stop sign)
# 34    0.0576                               (stop sign, car)
# 35    0.0278                       (person, stop sign, car)
# 36    0.0268                                (person, train)
# 37    0.0276                         (traffic light, train)
# 38    0.0206                                 (train, bench)
# 39    0.1902                        (person, traffic light)
# 40    0.1978                           (traffic light, car)
# 41    0.1362                   (person, car, traffic light)
# 42    0.2386                                  (person, car)
# 43    0.0712                                   (bench, car)
# 44    0.0604                           (person, bench, car)
# 45    0.1032                                   (car, truck)
# 46    0.0778                         (traffic light, truck)
# 47    0.0828                                (person, truck)
# 48    0.0210                          (fire hydrant, truck)
# 49    0.0660                    (traffic light, car, truck)
# 50    0.0520                 (person, truck, traffic light)
# 51    0.0436            (person, car, truck, traffic light)
# 52    0.0656                           (person, car, truck)
# 53    0.0668                           (traffic light, bus)
# 54    0.0656                                     (car, bus)
# 55    0.0230                                   (truck, bus)
# 56    0.0762                                  (person, bus)
# 57    0.0208                                 (handbag, bus)
# 58    0.0558                   (person, bus, traffic light)
# 59    0.0526                      (traffic light, car, bus)
# 60    0.0544                             (person, car, bus)
# 61    0.0438              (person, car, bus, traffic light)
# 62    0.0202                              (truck, car, bus)
# 63    0.0208                         (person, handbag, bus)
# 64    0.0390                           (parking meter, car)
# 65    0.0274                        (parking meter, person)
# 66    0.0212                   (parking meter, person, car)
# 67    0.0224                                (person, clock)
# 68    0.0826                             (person, backpack)
# 69    0.0356                                (car, backpack)
# 70    0.0352                      (traffic light, backpack)
# 71    0.0316                            (handbag, backpack)
# 72    0.0400                              (bench, backpack)
# 73    0.0350                        (person, car, backpack)
# 74    0.0348              (person, traffic light, backpack)
# 75    0.0226                 (traffic light, car, backpack)
# 76    0.0224         (person, traffic light, car, backpack)
# 77    0.0314                    (person, handbag, backpack)
# 78    0.0380                      (person, bench, backpack)
# 79    0.0666                              (person, bicycle)
# 80    0.0420                                 (bicycle, car)
# 81    0.0348                       (traffic light, bicycle)
# 82    0.0252                               (bicycle, bench)
# 83    0.0388                         (person, bicycle, car)
# 84    0.0328               (person, bicycle, traffic light)
# 85    0.0260                  (traffic light, bicycle, car)
# 86    0.0246          (person, bicycle, car, traffic light)
# 87    0.0220                       (person, bicycle, bench)
# 88    0.0340                          (bench, dining table)
# 89    0.0292                         (person, dining table)
# 90    0.0254                  (person, bench, dining table)
# 91    0.0430                             (person, umbrella)
# 92    0.0272                              (umbrella, bench)
# 93    0.0204                                (umbrella, car)
# 94    0.0238                      (umbrella, person, bench)
# 95    0.0506                                 (chair, bench)
# 96    0.0474                                (person, chair)
# 97    0.0394                         (person, chair, bench)
# 98    0.0342                           (person, skateboard)
# 99    0.0254                            (bench, skateboard)
# 100   0.0254                    (person, bench, skateboard)
# 101   0.0360                          (person, sports ball)
# 102   0.0350                           (bench, sports ball)
# 103   0.0342                   (person, bench, sports ball)
# 104   0.0212                        (tennis racket, person)
# 105   0.0210                         (tennis racket, bench)
# 106   0.0208                 (tennis racket, person, bench)
# 107   0.0342                           (motorcycle, person)
# 108   0.0302                              (motorcycle, car)
# 109   0.0244                    (motorcycle, traffic light)
# 110   0.0252                      (motorcycle, person, car)
# 111   0.0220            (motorcycle, person, traffic light)
# 112   0.0200               (motorcycle, traffic light, car)
# 113   0.1224                              (person, handbag)
# 114   0.0574                                 (handbag, car)
# 115   0.0518                       (traffic light, handbag)
# 116   0.0584                               (handbag, bench)
# 117   0.0572                         (person, handbag, car)
# 118   0.0518               (person, handbag, traffic light)
# 119   0.0366                  (traffic light, handbag, car)
# 120   0.0366          (person, handbag, car, traffic light)
# 121   0.0580                       (person, handbag, bench)
# 122   0.0622                            (fire hydrant, car)
# 123   0.0538                         (person, fire hydrant)
# 124   0.0204                  (traffic light, fire hydrant)
# 125   0.0318                    (person, car, fire hydrant)
# 126   0.0332                         (baseball bat, person)
# 127   0.0324                          (baseball bat, bench)
# 128   0.0322                  (baseball bat, person, bench)
# 129   0.0298                       (person, baseball glove)
# 130   0.0292                        (baseball glove, bench)
# 131   0.0242                 (baseball bat, baseball glove)
# 132   0.0290                (person, baseball glove, bench)
# 133   0.0242         (baseball bat, person, baseball glove)
# 134   0.0238          (baseball bat, baseball glove, bench)
# 135   0.0238  (baseball bat, person, baseball glove, bench)
# 136   0.0350                           (cell phone, person)
# 137   0.0240                            (cell phone, bench)
# 138   0.0238                    (cell phone, person, bench)
# 139   0.0244                                (bench, bottle)
# 140   0.0226                               (person, bottle)
# 141   0.0202                        (person, bench, bottle)
# 142   0.0286                          (potted plant, bench)
# 143   0.0228                         (person, potted plant)
# [39, '000000048632.png', 48632]
# [168, '000000349698.png', 349698]
# [209, '000000401439.png', 401439]
# [237, '000000289194.png', 289194]
# [241, '000000477585.png', 477585]
# [279, '000000130735.png', 130735]
# [301, '000000190738.png', 190738]
# [386, '000000123692.png', 123692]
# [395, '000000229001.png', 229001]
# [407, '000000165945.png', 165945]
# [436, '000000326832.png', 326832]
# [491, '000000357673.png', 357673]
# [504, '000000190994.png', 190994]
# [518, '000000284012.png', 284012]
# [552, '000000439084.png', 439084]
# [604, '000000288440.png', 288440]
# [620, '000000120407.png', 120407]
# [626, '000000206039.png', 206039]
# [660, '000000340314.png', 340314]
# [715, '000000179997.png', 179997]
# [735, '000000529665.png', 529665]
# [811, '000000442165.png', 442165]
# [832, '000000457437.png', 457437]
# [891, '000000245336.png', 245336]
# [894, '000000324904.png', 324904]
# [901, '000000005608.png', 5608]
# [1001, '000000397605.png', 397605]
