# %% [markdown]
# # Feature extraction
#
# textual documents can be converted in hot encoding and creating a mere presence/absence of the word, the drawbacks is that frequent words have high scores for almost all documents (ex the). Use TF-IDF the word is interesting if it shows a lot of times in few documents, vice versa, it's not interesting if it shows too many times in too many documents
# <br>
# NOTE: commas, and stop words are reduced <br>
# To reduce dimensionality we can use the pca approach (to use a linear combination of the feature) <br>
# as usual determine the knee point technique to find out how many points should be kept <br>
#
# # IMPUTERS
# can fill missing values easily with what we expect there to be: can use univariate approach (ex 0, mean) or infer the value from similar specimens <br>
# the simple imputers fills the missing value with a constant or the mean height<br>
# we can also use a more intelligent imputer (ex KNN imputer) which gives a value based on the nearest neighbors value (which uses a re defined version of distances only computed on the distance for which i have no missing value [just for the two values, not for every value])

# %%
from sklearn.feature_extraction.text import TfidfTransformer

from sklearn.decomposition import PCA

# %%
import pandas as pd

with open('dati.txt', 'r', encoding='UTF-8') as fp:
    df = pd.DataFrame([[' '.join(line.split(',')[:-1]), line.strip().split(',')[-1]] for line in fp], columns=['review', 'label'])

df = df.iloc[1:, :]    

from sklearn.model_selection import train_test_split


X = df.loc[:, 'review']
y = df.loc[:, 'label']
display(df)
# Stratify to have the same distribution and no different values
xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.25)


# Count ìVectorize to split the word in words and count
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

pipe = make_pipeline(CountVectorizer(stop_words='english'), DecisionTreeClassifier(max_depth=10)).fit(xTrain, yTrain)


yPred = pipe.predict(xTest)

from sklearn.metrics import accuracy_score
accuracy_score(yTest, yPred)*100
# Out:
#                                                   review label
# 1      "For a movie that gets no respect there sure a...     1
# 2      "Working with one of the best Shakespeare sour...     0
# 3      "Bizarre horror movie filled with famous faces...     1
# 4      "Well...tremors I  the original started off in...     0
# 5      "A solid  if unremarkable film. Matthau  as Ei...     1
# ...                                                  ...   ...
# 24996  "Oh  those Italians! Assuming that movies abou...     0
# 24997  "Great movie -I loved it. Great editing and us...     1
# 24998  "Eight academy nominations? It's beyond belief...     0
# 24999  "Enchanted April is a tone poem  an impression...     1
# 25000  "Not that I dislike childrens movies  but this...     0
#
# [25000 rows x 2 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[56], line 23
# ...

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt
import numpy as np

# fig, ax = plt.subplots(figsize=(14,16))
# plot_tree(pipe[1], ax=ax, feature_names=pipe[0].get_feature_names_out());


pipe[0].get_feature_names_out()[np.argsort(pipe[1].feature_importances_)[-10:]]
plt.bar(pipe[0].get_feature_names_out()[np.argsort(pipe[1].feature_importances_)[-10:]], height=np.argsort(pipe[1].feature_importances_)[-10:])
# Out:
# <BarContainer object of 10 artists>
# Error in callback <function flush_figures at 0x0000020BF574C4A0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\utente\OneDrive\Desktop\Magistrale\01TWZSM_DataScienceLab\.venv\Lib\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File c:\Users\utente\OneDrive\Desktop\Magistrale\01TWZSM_DataScienceLab\.venv\Lib\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
# ...

# %%
pipe = make_pipeline(TfidfVectorizer(stop_words='english'), DecisionTreeClassifier())

# %%
grid = {'decisiontreeclassifier__max_depth':[2,10,None], 
        #'decisiontreeclassifier__min_impurity_decreased':[0, 0.01, 0.1],
        'tfidfvectorizer__max_features':[100, 500, 1000, None]}

from sklearn.model_selection import ParameterGrid

from sklearn.model_selection import GridSearchCV
# use n_jobs -1 to parallelize as much as possible the executiton
gs = GridSearchCV(pipe, grid, scoring='accuracy', cv=3, n_jobs=1).fit(xTrain, yTrain)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[50], line 8
#       5 from sklearn.model_selection import ParameterGrid
#       7 from sklearn.model_selection import GridSearchCV
# ----> 8 gs = GridSearchCV(pipe, grid, scoring='accuracy', cv=3, n_jobs=1).fit(xTrain, yTrain)
#
# File c:\Users\utente\OneDrive\Desktop\Magistrale\01TWZSM_DataScienceLab\.venv\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# ...
